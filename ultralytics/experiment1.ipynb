# %%
# !unzip 'D:\TA\Project\Cric.zip'

# %%
from ultralytics import YOLO
model = YOLO("ultralytics/cfg/models/v8/yolov8n_cbam.yaml")
model.info()        # menampilkan ringkasan arsitektur
# Out:
# WARNING Unable to automatically guess model task, assuming 'task=detect'. Explicitly define task for your model, i.e. 'task=detect', 'segment', 'classify','pose' or 'obb'.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[1], line 2
#       1 from ultralytics import YOLO
# ----> 2 model = YOLO("ultralytics/cfg/models/v8/yolov8n_cbam.yaml")
#       3 model.info()        # menampilkan ringkasan arsitektur
#
# File D:\TA\Project\ultralytics\ultralytics\models\yolo\model.py:83, in YOLO.__init__(self, model, task, verbose)
#      80     self.__dict__ = new_instance.__dict__
#      81 else:
#      82     # Continue with default YOLO initialization
# ---> 83     super().__init__(model=model, task=task, verbose=verbose)
#      84     if hasattr(self.model, "model") and "RTDETR" in self.model.model[-1]._get_name():  # if RTDETR head
# ...

# %%
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu121
# WARNING: Ignoring invalid distribution -ip (d:\ta\project\viume\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\ta\project\viume\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\ta\project\viume\lib\site-packages)
# ...
#      ---------------------------------------- 4.1/4.1 MB 16.5 MB/s  0:00:00
# ...
# INFO: pip is looking at multiple versions of torchaudio to determine which version is compatible with other requirements. This could take a while.
# ...
#      ---------------------------------------- 4.1/4.1 MB 14.6 MB/s  0:00:00
# ...
#      ---------------------------------------- 4.1/4.1 MB 12.3 MB/s  0:00:00
# ...
#      ---------------------------------------- 4.1/4.1 MB 11.7 MB/s  0:00:00
# ...
#      ---------------------------------------- 4.1/4.1 MB 15.2 MB/s  0:00:00
# ...
#      ---------------------------------------- 4.1/4.1 MB 10.1 MB/s  0:00:00
# ...

# %%
import torch, torchvision, torchaudio
print(torch.__version__, torchvision.__version__, torchaudio.__version__)
print(torch.cuda.is_available(), torch.version.cuda)
# Out:
# 2.5.1+cu121 0.20.1+cu121 2.5.1+cu121
# True 12.1

# %%
# !cd..

# %%
# %pwd
# Out:
# 'd:\\TA\\Project\\ultralytics\\ultralytics'

# %%
import sys
sys.path.append(r"D:/TA/Project/ultralytics")
from scripts.wbf_eval_model import evaluate_wbf

result = evaluate_wbf(r"D:/TA/Project/cric/data.yaml")
print(result)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[19], line 3
#       1 import sys
#       2 sys.path.append(r"D:/TA/Project/ultralytics")
# ----> 3 from scripts.wbf_eval_model import evaluate_wbf
#       5 result = evaluate_wbf(r"D:/TA/Project/cric/data.yaml")
#       6 print(result)
#
# ModuleNotFoundError: No module named 'scripts.wbf_eval_model'
